# %%
import pandas as pd

# %%
df = pd.read_csv('3pages.csv')
df.head(30)
# Out:
#                                                 title  year  \
# 0   A review of explainable deep learning cancer d...  2021
# 1   Applications and limitations of machine learni...  2019
# 2   [HTML][HTML] Machine learning applications in ...  2021
# 3   A deep learning approach for cancer detection ...  2017
# 4   [HTML][HTML] Breast cancer detection by levera...  2020
# 5   Breast cancer detection using machine learning...  2018
# 6   Deep learning for lung Cancer detection and cl...  2020
# 7   Analysis of breast cancer detection using diff...  2020
# 8   Deep learning for image-based cancer detection...  2018
# 9   Deep learning in breast cancer detection and c...  2020
# 10  [HTML][HTML] Machine learning in radiation onc...  2018
# 11  Skin cancer detection: a review using deep lea...  2021
# 12  Big data and machine learning in radiation onc...  2016
# 13  [HTML][HTML] Deep learning to improve breast c...  2019
# 14    Lung cancer detection: a deep learning approach  2019
# ...

# %%
df.sort_values([ 'journal', 'year', 'citations'], ascending = [True, False, True])
# Out:
#                                                 title  year  \
# 2   [HTML][HTML] Machine learning applications in ...  2021
# 26  Breast cancer detection using an ensemble deep...  2021
# 4   [HTML][HTML] Breast cancer detection by levera...  2020
# 22  [HTML][HTML] Recent advancement in cancer dete...  2020
# 8   Deep learning for image-based cancer detection...  2018
# 12  Big data and machine learning in radiation onc...  2016
# 28  Medical Internet of things using machine learn...  2020
# 3   A deep learning approach for cancer detection ...  2017
# 9   Deep learning in breast cancer detection and c...  2020
# 7   Analysis of breast cancer detection using diff...  2020
# 18  Deep learning solutions for skin cancer detect...  2020
# 6   Deep learning for lung Cancer detection and cl...  2020
# 14    Lung cancer detection: a deep learning approach  2019
# 1   Applications and limitations of machine learni...  2019
# 16  On breast cancer detection: an application of ...  2018
# ...
